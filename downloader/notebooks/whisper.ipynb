# %%
import whisper

# %%
model = whisper.load_model("base")
result = model.transcribe("/home/emanuele/Downloads/tg lis.mp4")
# Out:
# /home/emanuele/Dottorato/DigitalHuman/downloader/venv/lib/python3.11/site-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
for k,v in result.items():
    print(f'key:{k}')
    print(f'value:{v}')
# Out:
# key:text
# ...

# %%
transcript = result['text']
segments = result['segments']

# %%
# Salva la trascrizione in un file
with open("transcript.txt", "w") as f:
    f.write(transcript)

# Salva i segmenti (timestamp) in un file
with open("timestamps.txt", "w") as f:
    for segment in segments:
        f.write(f"{segment['start']} - {segment['end']}, {segment['text']}\n")

# %%
round(segment['end'], 3)
# Out:
# 827.92

# %%
video = '/home/emanuele/Dottorato/DigitalHuman/downloader/test/test_lis.mp4'

# %%
import os
os.path.basename(video).split('.')[0]
# Out:
# 'test_lis'

# %%
def std_str(string: str):
    return string.replace(" ", "_").replace("-", "_")


path = 'output/Tg Noi Lis ｜ 27⧸04⧸2022.mp4'
std_str(path)
# Out:
# 'output/Tg_Noi_Lis_｜_27⧸04⧸2022.mp4'

# %%
import yt_dlp
import os

def download_audio(url, output_path):
    ydl_opts = {
        "format": "bestaudio/best",
        "outtmpl": output_path + "%(title)s.%(ext)s",
        "postprocessors": [
            {
                "key": "FFmpegExtractAudio",
                "preferredcodec": "mp3",
                "preferredquality": "192",
            },
        ],
    }

    if isinstance(url, list):
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download(url)
    else:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(url)
            ydl.download([url])

    os.rename(
        output_path + info_dict["title"] + ".mp3",
        output_path + std_str(info_dict["title"]) + ".mp3",
    )

# %%
download_audio("https://www.youtube.com/watch?v=uk6S6j6dJTc", 'output/')
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uk6S6j6dJTc
# [youtube] uk6S6j6dJTc: Downloading webpage
# [youtube] uk6S6j6dJTc: Downloading ios player API JSON
# [youtube] uk6S6j6dJTc: Downloading android player API JSON
# [youtube] uk6S6j6dJTc: Downloading m3u8 information
# [info] uk6S6j6dJTc: Downloading 1 format(s): 251
# [download] Destination: output/Tg Noi Lis ｜ 27⧸04⧸2022.webm
# [download] 100% of   10.33MiB in 00:00:01 at 7.95MiB/s
# [ExtractAudio] Destination: output/Tg Noi Lis ｜ 27⧸04⧸2022.mp3
# Deleting original file output/Tg Noi Lis ｜ 27⧸04⧸2022.webm (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uk6S6j6dJTc
# [youtube] uk6S6j6dJTc: Downloading webpage
# [youtube] uk6S6j6dJTc: Downloading ios player API JSON
# [youtube] uk6S6j6dJTc: Downloading android player API JSON
# [youtube] uk6S6j6dJTc: Downloading m3u8 information
# [info] uk6S6j6dJTc: Downloading 1 format(s): 251
# ...
